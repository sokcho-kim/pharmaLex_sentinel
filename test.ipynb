# %%
import pandas as pd

# 파일 로드
file = r"C:\Jimin\pharmaLex_sentinel\data\요양심사약제_후처리.xlsx"
df = pd.read_excel(file)

# '�' 포함된 셀 찾기
mask = df.applymap(lambda x: isinstance(x, str) and '�' in x)

# 위치와 값 출력
errors = []
for col in df.columns:
    for idx in df.index[mask[col]]:
        errors.append([idx, col, df.at[idx, col]])

errors_df = pd.DataFrame(errors, columns=["row", "column", "value"])

# 빈도표 (컬럼별 건수)
freq = errors_df['column'].value_counts()

# 저장
errors_df.to_csv("unit_errors_full_list.csv", index=False, encoding="utf-8-sig")
freq.to_csv("unit_errors_summary.csv", encoding="utf-8-sig")

print("총 오류 건수:", len(errors_df))
print(freq)
# Out:
# 총 오류 건수: 54
# column
# 세부인정기준 및 방법    45
# 구분              9
# Name: count, dtype: int64
# C:\Users\sokch\AppData\Local\Temp\ipykernel_27536\3106701975.py:8: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   mask = df.applymap(lambda x: isinstance(x, str) and '�' in x)

# %%
# -*- coding: utf-8 -*-
import os
import pandas as pd

excel_path = r"C:\Jimin\pharmaLex_sentinel\data\요양심사약제_후처리.xlsx"
out_dir = os.path.join(os.path.dirname(excel_path), "out_scan")
os.makedirs(out_dir, exist_ok=True)

full_list_csv     = os.path.join(out_dir, "invalid_char_full_list.csv")
by_sheet_csv      = os.path.join(out_dir, "invalid_char_by_sheet.csv")
by_sheet_col_csv  = os.path.join(out_dir, "invalid_char_by_sheet_col.csv")

target_char = "�"  # U+FFFD replacement

def scan_workbook(path):
    xls = pd.ExcelFile(path)
    rows = []

    for sheet in xls.sheet_names:
        # 모든 값을 문자열로 강제 (깨짐 탐지 정확도 ↑)
        df = pd.read_excel(path, sheet_name=sheet, dtype=str)
        for r_idx in range(len(df)):
            for col in df.columns:
                val = df.iat[r_idx, df.columns.get_loc(col)]
                if pd.isna(val):
                    continue
                s = str(val)
                if target_char in s:
                    cnt = s.count(target_char)  # 셀 내 다중 발생 집계
                    rows.append({
                        "sheet": sheet,
                        "row": r_idx + 2,      # 엑셀 표시행(헤더 보정)
                        "column": col,
                        "count_in_cell": cnt,
                        "value": s[:200]       # 너무 길면 미리보기 200자
                    })
    return pd.DataFrame(rows)

df = scan_workbook(excel_path)

# 저장 & 요약
df.to_csv(full_list_csv, index=False, encoding="utf-8-sig")

if df.empty:
    print("검출 0건")
else:
    # 시트별 합계(다중 발생 합계)
    by_sheet = df.groupby("sheet")["count_in_cell"].sum().reset_index().sort_values("count_in_cell", ascending=False)
    by_sheet.to_csv(by_sheet_csv, index=False, encoding="utf-8-sig")

    # 시트-컬럼 피벗(다중 발생 합계)
    by_sheet_col = df.pivot_table(index="sheet", columns="column", values="count_in_cell", aggfunc="sum", fill_value=0)
    by_sheet_col.to_csv(by_sheet_col_csv, encoding="utf-8-sig")

    print("총 발생 개수(셀 내 중복 포함):", int(df["count_in_cell"].sum()))
    print("총 셀 개수(하나 이상 포함한 셀 수):", len(df))
    print("상위 10행 미리보기:")
    print(df.head(10))
    print("\n요약(시트별):")
    print(by_sheet.head(10))
# Out:
# 총 발생 개수(셀 내 중복 포함): 94
# 총 셀 개수(하나 이상 포함한 셀 수): 54
# 상위 10행 미리보기:
#     sheet  row       column  count_in_cell  \
# 0  Sheet1   34  세부인정기준 및 방법              1
# 1  Sheet1   37  세부인정기준 및 방법              4
# 2  Sheet1  124  세부인정기준 및 방법              2
# 3  Sheet1  131  세부인정기준 및 방법              1
# 4  Sheet1  132  세부인정기준 및 방법              1
# 5  Sheet1  133  세부인정기준 및 방법              1
# 6  Sheet1  141  세부인정기준 및 방법              1
# 7  Sheet1  142  세부인정기준 및 방법              1
# 8  Sheet1  147  세부인정기준 및 방법              2
# 9  Sheet1  153  세부인정기준 및 방법              3
#
#                                                value
# 0  1. 만성신부전증환자(혈액투석 및 복막투석환자) 가. 혈압강하제(고혈압 치료제) 1...
# 1  1. 허가사항 범위 내에서 아래와 같은 기준으로 투여시 요양 급여를 인정하며, 동 ...
# 2  허가사항 범위 내에서 아래와 같은 기준으로 투여 시 요양 급여를 인정하며, 동 인정...
# 3  허가사항 범위 내에서 아래와 같은 기준으로 투여 시 요양 급여를 인정하며, 동 인정...
# 4  1. 허가사항 범위 내에서 아래와 같은 기준으로 투여 시 요양급여를 인정하며, 동 ...
# 5  1. 허가사항 범위 내에서 아래와 같은 기준으로 투여 시 요양급여를 인정하며, 동 ...
# 6  1. 허가사항 범위 내에서 아래와 같은 기준으로 투여 시 요양급여를 인정하며, 동 ...
# 7  허가사항 범위 내에서 아래와 같은 기준으로 투여 시 요양 급여를 인정하며, 동 인정...
# 8  허가사항 범위 내에서 아래와 같은 기준으로 투여 시 요양 급여를 인정하며, 동 인정...
# 9  허가사항 범위 내에서 아래와 같은 기준으로 투여 시 요양급 여를 인정하며, 동 인정...
#
# 요약(시트별):
#     sheet  count_in_cell
# 0  Sheet1             94

# %%
import pandas as pd

file = r"C:\Jimin\pharmaLex_sentinel\data\요양심사약제_후처리.xlsx"
df = pd.read_excel(file, dtype=str)

total_chars = 0
cells_with_err = 0

for col in df.columns:
    for val in df[col].dropna():
        if "�" in val:
            cnt = val.count("�")
            total_chars += cnt
            cells_with_err += 1

print("셀 수:", cells_with_err)   # 형님이 본 94
print("문자 수:", total_chars)   # 형님이 찾기에서 본 1655
# Out:
# 셀 수: 54
# 문자 수: 94

# %%
import pandas as pd

file = r"C:\Jimin\pharmaLex_sentinel\data\요양심사약제_후처리.xlsx"
df = pd.read_excel(file, dtype=str)

chars = {}

for col in df.columns:
    for val in df[col].dropna():
        for ch in val:
            if ord(ch) > 127:  # 비ASCII 문자만 체크
                chars[ord(ch)] = chars.get(ord(ch), 0) + 1

for code, cnt in sorted(chars.items()):
    print(hex(code), chr(code), cnt)
# Out:
# 0xb0 ° 12
# 0xb2 ² 8
# 0xb5 µ 6
# 0xb7 · 455
# 0xb9 ¹ 2
# 0xd7 × 4
# 0x2bc ʼ 1
# 0x3b1 α 4
# 0x3bc μ 1
# 0x2013 – 6
# 0x2018 ‘ 3
# 0x2019 ’ 3
# 0x2020 † 1
# 0x203b ※ 322
# 0x2076 ⁶ 4
# 0x2082 ₂ 1
# 0x2192 → 9
# 0x2264 ≤ 23
# 0x2265 ≥ 93
# 0x2300 ⌀ 7
# 0x2460 ① 42
# 0x2461 ② 37
# 0x2462 ③ 19
# 0x2463 ④ 19
# 0x2464 ⑤ 15
# 0x2465 ⑥ 6
# 0x2466 ⑦ 4
# 0x2467 ⑧ 4
# 0x2468 ⑨ 10
# 0x25cb ○ 295
# 0x3001 、 1
# 0x3002 。 11
# 0x300c 「 78
# 0x300d 」 79
# 0x300e 『 1
# 0x304f く 7
# 0x338d ㎍ 2
# 0x4e00 一 1
# 0x5168 全 1
# 0x5668 器 1
# 0x571f 土 1
# 0x75b9 疹 1
# 0x75d2 痒 1
# 0x809d 肝 1
# 0x80c3 胃 1
# 0x81d3 臓 1
# 0xac00 가 4693
# 0xac01 각 223
# 0xac04 간 950
# 0xac08 갈 21
# 0xac10 감 600
# 0xac11 갑 27
# 0xac12 값 488
# 0xac15 강 216
# 0xac16 갖 4
# 0xac19 같 609
# 0xac1c 개 919
# 0xac1d 객 33
# 0xac31 갱 7
# 0xac70 거 494
# 0xac74 건 324
# 0xac77 걷 1
# 0xac78 걸 30
# 0xac80 검 360
# 0xac81 겁 2
# 0xac83 것 73
# 0xac8c 게 186
# 0xac90 겐 11
# 0xac94 겔 4
# 0xaca8 겨 1
# 0xaca9 격 125
# 0xacac 견 195
# 0xacb0 결 386
# 0xacb9 겹 1
# 0xacbd 경 3640
# 0xacc4 계 319
# 0xace0 고 1708
# 0xace1 곡 4
# 0xace4 곤 54
# 0xace8 골 300
# 0xacf0 곰 1
# 0xacf5 공 176
# 0xacfc 과 1401
# 0xacfd 곽 1
# 0xad00 관 1061
# 0xad04 괄 1
# 0xad11 광 72
# 0xad34 괴 57
# 0xad50 교 205
# 0xad6c 구 910
# 0xad6d 국 74
# 0xad70 군 233
# 0xad74 굴 10
# 0xad81 궁 38
# 0xad8c 권 59
# 0xada4 궤 135
# 0xadc0 귀 10
# 0xaddc 규 16
# 0xade0 균 169
# 0xade4 귤 4
# 0xadf8 그 239
# 0xadf9 극 52
# 0xadfc 근 216
# 0xae00 글 65
# 0xae08 금 117
# 0xae09 급 1527
# 0xae30 기 3091
# 0xae34 긴 35
# 0xae38 길 21
# 0xae4c 까 285
# 0xae68 깨 6
# 0xaebc 꺼 1
# 0xaed8 께 18
# 0xaef4 껴 1
# 0xafb9 꾹 5
# 0xafbc 꾼 1
# 0xb053 끓 1
# 0xb05d 끝 4
# 0xb098 나 1620
# 0xb099 낙 6
# 0xb09c 난 85
# 0xb0a0 날 30
# 0xb0a8 남 51
# 0xb0ac 났 1
# 0xb0ad 낭 13
# 0xb0ae 낮 20
# 0xb0b4 내 1362
# 0xb0c4 냄 3
# 0xb0c5 냅 1
# 0xb0c9 냉 14
# 0xb0e5 냥 2
# 0xb108 너 18
# 0xb110 널 4
# 0xb118 넘 4
# 0xb124 네 19
# 0xb125 넥 8
# 0xb134 넴 1
# 0xb140 녀 3
# 0xb141 녁 1
# 0xb144 년 159
# 0xb155 녕 5
# 0xb178 노 73
# 0xb179 녹 18
# 0xb17c 논 4
# 0xb180 놀 11
# 0xb18d 농 53
# 0xb192 높 35
# 0xb1cc 뇌 195
# 0xb1e8 뇨 174
# 0xb204 누 33
# 0xb208 눈 13
# 0xb20c 눌 1
# 0xb274 뉴 23
# 0xb284 늄 3
# 0xb290 느 27
# 0xb291 늑 11
# 0xb294 는 3936
# 0xb298 늘 2
# 0xb2a5 능 432
# 0xb2a6 늦 1
# 0xb2c8 니 139
# 0xb2cc 닌 37
# 0xb2d0 닐 7
# 0xb2d8 님 2
# 0xb2e4 다 1543
# 0xb2e5 닥 5
# 0xb2e8 단 844
# 0xb2eb 닫 14
# 0xb2ec 달 56
# 0xb2f4 담 522
# 0xb2f5 답 21
# 0xb2f9 당 446
# 0xb300 대 1263
# 0xb354 더 43
# 0xb358 던 15
# 0xb364 덤 3
# 0xb367 덧 2
# 0xb369 덩 3
# 0xb370 데 14
# 0xb371 덱 9
# 0xb374 덴 2
# 0xb378 델 5
# 0xb3c4 도 1080
# 0xb3c5 독 127
# 0xb3c8 돈 1
# 0xb3cc 돌 20
# 0xb3d9 동 1485
# 0xb418 되 578
# 0xb41c 된 438
# 0xb420 될 18
# 0xb428 됨 36
# 0xb450 두 287
# 0xb454 둔 3
# 0xb458 둘 4
# 0xb4b7 뒷 2
# 0xb4c0 듀 6
# 0xb4dc 드 383
# 0xb4dd 득 11
# 0xb4e0 든 13
# 0xb4e3 듣 1
# 0xb4e4 들 34
# 0xb4e6 듦 2
# 0xb4ec 듬 3
# 0xb4f1 등 1352
# 0xb514 디 61
# 0xb518 딘 7
# 0xb51c 딜 3
# 0xb525 딥 1
# 0xb530 따 246
# 0xb538 딸 5
# 0xb540 땀 10
# 0xb54c 때 92
# 0xb5a0 떠 1
# 0xb5a8 떨 1
# 0xb610 또 842
# 0xb69c 뚜 2
# 0xb77c 라 522
# 0xb77d 락 28
# 0xb780 란 99
# 0xb784 랄 4
# 0xb78c 람 66
# 0xb78d 랍 3
# 0xb791 랑 4
# 0xb798 래 1253
# 0xb799 랙 1
# 0xb79c 랜 6
# 0xb7a8 램 110
# 0xb7ab 랫 1
# 0xb7b5 략 2
# 0xb7c9 량 579
# 0xb7ec 러 136
# 0xb7ed 럭 3
# 0xb7f0 런 3
# 0xb7fc 럼 2
# 0xb7fd 럽 25
# 0xb808 레 182
# 0xb809 렉 14
# 0xb80c 렌 18
# 0xb810 렐 8
# 0xb818 렘 7
# 0xb819 렙 4
# 0xb81b 렛 2
# 0xb824 려 107
# 0xb825 력 157
# 0xb828 련 124
# 0xb834 렴 62
# 0xb837 렷 2
# 0xb839 령 104
# 0xb840 례 45
# 0xb85c 로 2795
# 0xb85d 록 608
# 0xb860 론 104
# 0xb864 롤 20
# 0xb86c 롬 17
# 0xb86d 롭 1
# 0xb8b0 뢰 9
# 0xb8cc 료 1213
# 0xb8e1 룡 2
# 0xb8e8 루 114
# 0xb8f9 룹 3
# 0xb958 류 230
# 0xb95c 륜 1
# 0xb960 률 9
# 0xb968 륨 9
# 0xb974 르 321
# 0xb978 른 140
# 0xb97c 를 2333
# 0xb984 름 40
# 0xb98e 릎 1
# 0xb9ac 리 561
# 0xb9ad 릭 7
# 0xb9b0 린 225
# 0xb9b4 릴 4
# 0xb9bc 림 61
# 0xb9bd 립 43
# 0xb9c1 링 34
# 0xb9c8 마 405
# 0xb9c9 막 193
# 0xb9cc 만 944
# 0xb9ce 많 5
# 0xb9d0 말 92
# 0xb9d9 맙 1
# 0xb9dd 망 39
# 0xb9de 맞 1
# 0xb9e4 매 150
# 0xb9e5 맥 359
# 0xb9f7 맷 1
# 0xba38 머 30
# 0xba3c 먼 1
# 0xba40 멀 4
# 0xba48 멈 5
# 0xba54 메 60
# 0xba58 멘 1
# 0xba5c 멜 3
# 0xba70 며 721
# 0xba74 면 425
# 0xba78 멸 2
# 0xba85 명 767
# 0xbaa8 모 279
# 0xbaa9 목 149
# 0xbaac 몬 178
# 0xbab0 몰 2
# 0xbab8 몸 14
# 0xbabb 못 25
# 0xbb34 무 72
# 0xbb38 문 113
# 0xbb3c 물 128
# 0xbb3d 묽 1
# 0xbba4 뮤 8
# 0xbbac 뮬 1
# 0xbbc0 므 14
# 0xbbf8 미 335
# 0xbbf9 믹 3
# 0xbbfc 민 89
# 0xbc00 밀 126
# 0xbc0f 및 745
# 0xbc11 밑 4
# 0xbc14 바 231
# 0xbc15 박 57
# 0xbc18 반 777
# 0xbc1b 받 123
# 0xbc1c 발 617
# 0xbc24 밤 2
# 0xbc29 방 734
# 0xbc30 배 104
# 0xbc31 백 104
# 0xbc84 버 16
# 0xbc88 번 68
# 0xbc94 범 1026
# 0xbc95 법 852
# 0xbca0 베 79
# 0xbca1 벡 3
# 0xbca4 벤 9
# 0xbca8 벨 5
# 0xbcb3 벳 3
# 0xbcbc 벼 1
# 0xbcbd 벽 5
# 0xbcc0 변 237
# 0xbcc4 별 155
# 0xbcd1 병 851
# 0xbcf4 보 417
# 0xbcf5 복 289
# 0xbcf8 본 42
# 0xbcfc 볼 5
# 0xbd04 봄 1
# 0xbd09 봉 7
# 0xbd80 부 1846
# 0xbd84 분 583
# 0xbd88 불 352
# 0xbd89 붉 1
# 0xbd95 붕 3
# 0xbd99 붙 6
# 0xbdf0 뷰 3
# 0xbe0c 브 39
# 0xbe10 븐 5
# 0xbe14 블 3
# 0xbe44 비 543
# 0xbe45 빅 6
# 0xbe48 빈 115
# 0xbe4c 빌 14
# 0xbe5b 빛 4
# 0xbe60 빠 14
# 0xbee3 뻣 2
# 0xbf08 뼈 3
# 0xbfd0 뿐 2
# 0xc058 쁘 1
# 0xc060 쁠 1
# 0xc068 쁨 18
# 0xc0ac 사 3085
# 0xc0ad 삭 2
# 0xc0b0 산 250
# 0xc0b4 살 23
# 0xc0b6 삶 10
# 0xc0bc 삼 31
# 0xc0bd 삽 14
# 0xc0c1 상 2943
# 0xc0c8 새 19
# 0xc0c9 색 130
# 0xc0d8 샘 7
# 0xc0dd 생 443
# 0xc0f7 샷 1
# 0xc11c 서 1545
# 0xc11d 석 67
# 0xc11e 섞 1
# 0xc120 선 390
# 0xc124 설 85
# 0xc12c 섬 28
# 0xc12d 섭 11
# 0xc131 성 2826
# 0xc138 세 704
# 0xc139 섹 1
# 0xc13c 센 20
# 0xc140 셀 30
# 0xc149 셉 6
# 0xc154 셔 2
# 0xc158 션 3
# 0xc18c 소 1213
# 0xc18d 속 446
# 0xc190 손 83
# 0xc194 솔 6
# 0xc1a1 송 2
# 0xc1c4 쇄 50
# 0xc1e0 쇠 2
# 0xc1fc 쇼 3
# 0xc200 숀 2
# 0xc218 수 1207
# 0xc219 숙 29
# 0xc21c 순 106
# 0xc220 술 432
# 0xc228 숨 6
# 0xc26c 쉬 6
# 0xc270 쉰 1
# 0xc274 쉴 1
# 0xc27d 쉽 2
# 0xc288 슈 2
# 0xc290 슐 83
# 0xc298 슘 17
# 0xc2a4 스 677
# 0xc2a8 슨 22
# 0xc2ac 슬 17
# 0xc2b4 슴 18
# 0xc2b5 습 27
# 0xc2b9 승 98
# 0xc2dc 시 3029
# 0xc2dd 식 507
# 0xc2e0 신 887
# 0xc2e4 실 253
# 0xc2ec 심 543
# 0xc2ed 십 27
# 0xc2ef 싯 1
# 0xc2f1 싱 6
# 0xc2f8 싸 5
# 0xc313 쌓 1
# 0xc368 써 6
# 0xc36c 썬 1
# 0xc384 쎄 4
# 0xc410 쐐 2
# 0xc464 쑤 3
# 0xc4f0 쓰 9
# 0xc528 씨 9
# 0xc529 씩 36
# 0xc530 씰 2
# 0xc544 아 1771
# 0xc545 악 142
# 0xc548 안 307
# 0xc54a 않 333
# 0xc54c 알 184
# 0xc554 암 138
# 0xc555 압 200
# 0xc558 았 12
# 0xc559 앙 1
# 0xc55e 앞 1
# 0xc560 애 144
# 0xc561 액 731
# 0xc570 앰 8
# 0xc571 앱 1
# 0xc57c 야 370
# 0xc57d 약 1940
# 0xc584 얄 1
# 0xc587 얇 1
# 0xc591 양 1498
# 0xc5b4 어 250
# 0xc5b5 억 114
# 0xc5b8 언 1
# 0xc5bb 얻 2
# 0xc5bc 얼 11
# 0xc5c5 업 2
# 0xc5c6 없 460
# 0xc5c8 었 26
# 0xc5c9 엉 3
# 0xc5d0 에 4629
# 0xc5d1 엑 10
# 0xc5d4 엔 45
# 0xc5d8 엘 15
# 0xc5e0 엠 4
# 0xc5e1 엡 1
# 0xc5ec 여 6204
# 0xc5ed 역 271
# 0xc5f0 연 222
# 0xc5f4 열 127
# 0xc5fc 염 975
# 0xc5fd 엽 8
# 0xc600 였 97
# 0xc601 영 128
# 0xc606 옆 5
# 0xc608 예 212
# 0xc624 오 79
# 0xc625 옥 4
# 0xc628 온 17
# 0xc62c 올 13
# 0xc634 옴 1
# 0xc635 옵 2
# 0xc640 와 825
# 0xc644 완 63
# 0xc655 왕 8
# 0xc678 외 692
# 0xc694 요 1855
# 0xc695 욕 26
# 0xc6a9 용 2115
# 0xc6b0 우 2575
# 0xc6b4 운 100
# 0xc6b8 울 92
# 0xc6c0 움 23
# 0xc6c5 웅 2
# 0xc6cc 워 6
# 0xc6d0 원 708
# 0xc6d4 월 690
# 0xc6e0 웠 2
# 0xc6e8 웨 2
# 0xc6f0 웰 2
# 0xc6f9 웹 1
# 0xc704 위 1633
# 0xc708 윈 1
# 0xc70c 윌 4
# 0xc720 유 567
# 0xc721 육 55
# 0xc724 윤 2
# 0xc728 율 42
# 0xc735 융 8
# 0xc73c 으 1634
# 0xc740 은 1082
# 0xc744 을 1832
# 0xc74c 음 804
# 0xc751 응 463
# 0xc758 의 3601
# 0xc774 이 5206
# 0xc775 익 8
# 0xc778 인 3873
# 0xc77c 일 740
# 0xc784 임 311
# 0xc785 입 198
# 0xc788 있 601
# 0xc789 잉 5
# 0xc790 자 2725
# 0xc791 작 547
# 0xc794 잔 9
# 0xc798 잘 10
# 0xc7a0 잠 22
# 0xc7a1 잡 13
# 0xc7a5 장 970
# 0xc7a6 잦 1
# 0xc7ac 재 311
# 0xc800 저 321
# 0xc801 적 1181
# 0xc804 전 1616
# 0xc808 절 561
# 0xc80a 젊 1
# 0xc810 점 282
# 0xc811 접 29
# 0xc815 정 3120
# 0xc816 젖 1
# 0xc81c 제 4659
# 0xc81d 젝 10
# 0xc820 젠 4
# 0xc824 젤 6
# 0xc82c 젬 1
# 0xc82f 젯 3
# 0xc838 져 17
# 0xc83c 젼 2
# 0xc84c 졌 1
# 0xc870 조 562
# 0xc871 족 204
# 0xc874 존 92
# 0xc878 졸 65
# 0xc880 좀 1
# 0xc885 종 453
# 0xc88b 좋 9
# 0xc88c 좌 25
# 0xc8c4 죄 6
# 0xc8fc 주 1552
# 0xc8fd 죽 8
# 0xc900 준 1217
# 0xc904 줄 2
# 0xc911 중 1278
# 0xc950 쥐 2
# 0xc96c 쥬 5
# 0xc974 쥴 1
# 0xc988 즈 22
# 0xc989 즉 12
# 0xc998 즘 1
# 0xc999 즙 1
# 0xc99d 증 1803
# 0xc9c0 지 1911
# 0xc9c1 직 149
# 0xc9c4 진 697
# 0xc9c8 질 502
# 0xc9d0 짐 6
# 0xc9d1 집 36
# 0xc9d5 징 24
# 0xc9dc 짜 1
# 0xc9e7 짧 1
# 0xc9f8 째 89
# 0xcabd 쪽 3
# 0xcc14 찔 3
# 0xcc28 차 182
# 0xcc29 착 25
# 0xcc30 찰 25
# 0xcc38 참 86
# 0xcc3d 창 36
# 0xcc44 채 37
# 0xcc45 책 8
# 0xcc98 처 258
# 0xcc99 척 110
# 0xcc9c 천 147
# 0xcca0 철 28
# 0xcca8 첨 129
# 0xcca9 첩 1
# 0xccab 첫 71
# 0xccad 청 138
# 0xccb4 체 462
# 0xccc7 쳇 4
# 0xccd0 쳐 14
# 0xcd08 초 635
# 0xcd09 촉 17
# 0xcd1d 총 113
# 0xcd2c 촬 14
# 0xcd5c 최 501
# 0xcd94 추 277
# 0xcd95 축 68
# 0xcd98 춘 4
# 0xcd9c 출 320
# 0xcda5 춥 1
# 0xcda9 충 196
# 0xcdcc 췌 32
# 0xcde8 취 72
# 0xce04 츄 3
# 0xce20 츠 25
# 0xce21 측 85
# 0xce35 층 17
# 0xce58 치 1286
# 0xce59 칙 309
# 0xce5c 친 2
# 0xce60 칠 1
# 0xce68 침 88
# 0xce74 카 59
# 0xce75 칵 4
# 0xce78 칸 8
# 0xce7c 칼 32
# 0xce84 캄 2
# 0xce85 캅 15
# 0xce90 캐 1
# 0xce94 캔 4
# 0xce98 캘 1
# 0xcea1 캡 72
# 0xcee4 커 7
# 0xcef4 컴 1
# 0xcf00 케 23
# 0xcf08 켈 3
# 0xcf1c 켜 1
# 0xcf54 코 224
# 0xcf55 콕 1
# 0xcf58 콘 17
# 0xcf5c 콜 29
# 0xcf64 콤 4
# 0xcf67 콧 4
# 0xcf69 콩 1
# 0xcfe0 쿠 4
# 0xcfe8 쿨 4
# 0xd004 퀄 2
# 0xd034 퀴 5
# 0xd035 퀵 1
# 0xd038 퀸 7
# 0xd050 큐 8
# 0xd06c 크 138
# 0xd070 큰 6
# 0xd074 클 42
# 0xd0a4 키 28
# 0xd0a5 킥 1
# 0xd0a8 킨 29
# 0xd0ac 킬 17
# 0xd0b4 킴 4
# 0xd0b7 킷 1
# 0xd0c0 타 530
# 0xd0c1 탁 18
# 0xd0c4 탄 8
# 0xd0c8 탈 31
# 0xd0d0 탐 7
# 0xd0d1 탑 5
# 0xd0d5 탕 50
# 0xd0dc 태 188
# 0xd0dd 택 18
# 0xd130 터 219
# 0xd131 턱 3
# 0xd140 텀 1
# 0xd14c 테 198
# 0xd14d 텍 7
# 0xd150 텐 13
# 0xd154 텔 8
# 0xd15c 템 15
# 0xd15d 텝 1
# 0xd1a0 토 643
# 0xd1a1 톡 10
# 0xd1a4 톤 9
# 0xd1a8 톨 3
# 0xd1b1 톱 1
# 0xd1b5 통 416
# 0xd1f4 퇴 51
# 0xd22c 투 3796
# 0xd29c 튜 2
# 0xd2b8 트 220
# 0xd2b9 특 133
# 0xd2bc 튼 1
# 0xd2f0 티 178
# 0xd2f1 틱 4
# 0xd2f4 틴 36
# 0xd2f8 틸 8
# 0xd305 팅 8
# 0xd30c 파 261
# 0xd30d 팍 2
# 0xd310 판 277
# 0xd314 팔 8
# 0xd31c 팜 11
# 0xd321 팡 1
# 0xd328 패 113
# 0xd329 팩 4
# 0xd32c 팬 1
# 0xd33d 팽 14
# 0xd37c 퍼 15
# 0xd38c 펌 7
# 0xd398 페 100
# 0xd399 펙 2
# 0xd39c 펜 35
# 0xd3a9 펩 1
# 0xd3b4 펴 2
# 0xd3b8 편 87
# 0xd3c9 평 524
# 0xd3d0 폐 283
# 0xd3ec 포 465
# 0xd3ed 폭 1
# 0xd3f0 폰 6
# 0xd3f4 폴 9
# 0xd3fc 폼 3
# 0xd45c 표 76
# 0xd478 푸 17
# 0xd488 품 791
# 0xd48d 풍 20
# 0xd4e8 퓨 5
# 0xd504 프 212
# 0xd508 픈 7
# 0xd50c 플 69
# 0xd514 픔 3
# 0xd53c 피 277
# 0xd53d 픽 3
# 0xd540 핀 30
# 0xd544 필 304
# 0xd54d 핍 83
# 0xd558 하 3932
# 0xd559 학 271
# 0xd55c 한 2028
# 0xd560 할 321
# 0xd568 함 2526
# 0xd569 합 276
# 0xd56d 항 1613
# 0xd574 해 592
# 0xd575 핵 63
# 0xd578 핸 1
# 0xd588 했 13
# 0xd589 행 195
# 0xd5a5 향 21
# 0xd5c8 허 1034
# 0xd5cc 헌 4
# 0xd5d0 헐 7
# 0xd5d8 험 299
# 0xd5db 헛 4
# 0xd5e4 헤 47
# 0xd5e5 헥 3
# 0xd5ec 헬 22
# 0xd600 혀 3
# 0xd604 현 112
# 0xd608 혈 1339
# 0xd610 혐 1
# 0xd611 협 35
# 0xd614 혔 2
# 0xd615 형 376
# 0xd61c 혜 5
# 0xd638 호 1087
# 0xd639 혹 81
# 0xd63c 혼 23
# 0xd64d 홍 28
# 0xd654 화 416
# 0xd655 확 315
# 0xd658 환 2385
# 0xd65c 활 240
# 0xd669 황 84
# 0xd68c 회 562
# 0xd68d 획 3
# 0xd69f 횟 68
# 0xd6a1 횡 3
# 0xd6a8 효 420
# 0xd6c4 후 928
# 0xd6fc 훼 5
# 0xd734 휴 30
# 0xd749 흉 29
# 0xd750 흐 4
# 0xd751 흑 1
# 0xd754 흔 8
# 0xd758 흘 1
# 0xd761 흡 259
# 0xd765 흥 9
# 0xd769 흩 2
# 0xd76c 희 4
# 0xd788 히 90
# 0xd790 힐 6
# 0xd798 힘 6
# 0xd799 힙 4
# 0xfffd � 94
